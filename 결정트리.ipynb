# %% [markdown]
# ### 결정트리
# - 분류와 회귀작업 다중출력 작업도 가능한 다재다능한 머신러닝 알고리즘, 복잡한 데이터셋도 학습 가능
# - 랜덤포레스트의 기본구성

# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz, DecisionTreeRegressor

# %%
iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth = 2)
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
# export_graphviz(tree_clf, out_file=image_path('iris_tree.dot'),
#                 feature_names=iris.feature_names[2:],
#                 class_names=iris.target_names,
#                 rounded=True, filled=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tree_clf.predict_proba([[5,1.5]]) # 길이가 5cm , 너비가 1.5cm
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5,1.5]])
# Out:
# array([1])

# %% [markdown]
# #### 회귀
# ![image.png](data:image/png;base64,...)

# %%
tree_reg = DecisionTreeRegressor(max_depth = 2)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %% [markdown]
# #### 불안정성
# - 계단모양의 결정경계를 만듬
# - 훈련세트 회전에 민감 / 훈련데이터 작은 변화에도 민감
# - PCA기법으로 훈련데이터를 회전시킬 수 있음
